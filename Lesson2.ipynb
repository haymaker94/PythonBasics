# %%
#задание 1. Даны 2 переменных, в которых хранятся строки произвольной длины: phrase_1 и phrase_2.
#Напишите код, который проверяет какая из этих строк длиннее.
phrase_1 = "abcог"
phrase_2 = "abcd"
if len(phrase_1) > len(phrase_2):
    print('первая фраза длиннее')
elif len(phrase_1) == len(phrase_2):
    print('фразы равной длины')
else:
    print('вторая фраза длиннее')
# Out:
# первая фраза длиннее

# %%
#задание 2.Дана переменная, в которой хранится четырехзначное число (год).
#Необходимо написать программу, которая выведет, является ли данный год високосным или обычным.
#https://ru.wikipedia.org/wiki/Високосный_год
year = 1700
if year % 400 == 0 or (year % 4 == 0 and year % 100 != 0):
    print (str(year) + '-ый год - високосный')
else:
    print(str(year) + '-ый год НЕвисокосный')
# Out:
# 1700-ый год НЕвисокосный

# %%
#задание 3. Необходимо написать программу,
#которая будет запрашивать у пользователя месяц и дату рождения и выводить соответствующий знак зодиака.
day = int(input('Введите дату рождения: '))
month = int(input ('Введите номер месяца рождения: '))

#1 Овен (21 марта – 20 апреля)
if 31 >= day >= 21 and month == 3 or 20 >= day >= 1 and month == 4:
    print('Овен')
    
#2 Телец (21 апреля – 21 мая)
if 30 >= day >= 21 and month == 4 or 21 >= day >= 1 and month == 5:
    print('Телец')
    
#3 Близнецы (22 мая – 21 июня)
if  31 >= day >= 22 and month == 5 or 21 >= day >=1 and month == 6:
    print('Близнецы')
    
#4 Рак (22 июня – 22 июля)
if 30 >= day >= 22 and month == 6 or 22 >= day >=1 and month == 7:
    print('Рак')
    
#5 Лев (23 июля – 23 августа)
if 31 >= day >= 23 and month == 7 or 23 >= day >=1 and month == 8:
    print('Лев')
    
#6 Дева (24 августа – 23 сентября)
if 31 >= day >= 24 and month == 8 or 23 >= day >=1 and month == 9:
    print('Дева')
    
#7 Весы (24 сентября – 23 октября)
if 30 >= day >= 24 and month == 9 or 23 >= day >=1 and month == 10:
    print('Весы')
    
#8 Скорпион (24 октября – 22 ноября)
if 31 >= day >= 24 and month == 10 or 22 >= day >=1 and month == 11:
    print('Скорпион')
    
#9 Стрелец (23 ноября – 21 декабря)
if 30 >= day >=23 and month == 11 or 21 >= day >=1 and month == 12:
    print('Стрелец')
    
#10 Козерог (22 декабря – 20 января)
if 31 >= day >= 22 and month == 12 or 20 >= day >=1 and month == 1:
    print('Козерог')
    
#11 Водолей (21 января – 18 февраля)
if 31 >= day >= 21 and month == 1 or 18 >= day >=1 and month == 2:
    print('Водолей')
    
#12  Рыбы (19 февраля – 20 марта)
if 29 >= day >= 19 and month == 2 or 20 >= day >=1 and month == 3:
    print('Рыбы')

else:
    print ('что-то вы намутили с датами')
# Out:
# Введите дату рождения17
# Введите номер месяца рождения5
# Телец

# %%
#задание 4. Вам нужно написать программу для подбора упаковок по размерам товара. Размеры хранятся в переменных (в сантиметрах):
# width = 10, length = 205, height = 5. Используйте следующие правила:
#если каждое из трех измерений менее 15 сантиметров, то выведите на экран “Коробка №1”;
#если хотя бы одно из измерений больше 15 сантиметров, но менее 50 сантиметров, то выводите “Коробка №2”;
#если длина товара больше 2 метров, то выводите “Упаковка для лыж”;
#во всех остальных случаях выводите “Стандартная коробка №3”.

width, length, height = 10, 205, 5

if max(width, length, height) < 15:
    print ('Коробка №1')
elif length > 200:
    print ('Коробка для лыж')
elif 50 > width > 15 or 50 > length > 15 or 50 > height > 15:
    print ('Коробка №2')
else:
    print ('Коробка №3')
# Out:
# Коробка №1

# %%
#Задание 5 (необязательное) Дана переменная, в которой хранится шестизначное число (номер проездного билета).
#Напишите программу, которая будет определять, является ли данный билет “счастливым”.
#Билет считается счастливым, если сумма первых трех цифр совпадает с суммой последних трех цифр номера.

ticket = 123323
sum1 = (ticket // 100000) + (ticket // 10000 % 10) + (ticket // 1000 % 10)
sum2 = (ticket // 100 % 10) + (ticket // 10 % 10) + (ticket % 10)
if sum1 == sum2:
   print ('счастливый билет', sum1, sum2)
else:
    print('несчастливый билет', sum1, sum2)
# Out:
# несчастливый билет 6 8

# %%
#Задание 6 (необязательное) Напишите программу, которая сможет вычислять площади трех фигур (круг, треугольник и прямоугольник). Тип фигуры запрашиваем через пользовательский ввод, после чего делаем запрос характеристик фигуры:
#если пользователь выбрал круг, запрашиваем его радиус,
#если треугольник – длины трех его сторон;
#если прямоугольник – длины двух его сторон.
shape = input ('Введите тип фигуры: К-круг, Т-треугольник, П-прямоугольник ') 
if shape.lower() == "к":
    r = int(input ('введите радиус '))
    print ('площадь вашего круга равна ', r**2*3.1415)
if shape.lower() == "т":
    a = int(input ('введите длину первой стороны '))
    b = int(input ('введите длину второй стороны '))
    c = int(input ('введите длину третьей стороны '))
    p = (a+b+c)/2
    print ('площадь вашего треугольника равна ', (p*(p-a)*(p-b)*(p-c))**0.5)
if shape.lower() == "п":
    a = int(input ('введите длину первой стороны '))
    b = int(input ('введите длину второй стороны '))
    print ('площадь вашего прямоугольника равна ', a*b)
# Out:
# Введите тип фигуры: К-круг, Т-треугольник, П-прямоугольник П
# введите длину первой стороны 2
# введите длину второй стороны 4
# площадь вашего прямоугольника равна  8
